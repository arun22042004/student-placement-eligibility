# %%
# !pip install faker streamlit
# Out:
# Requirement already satisfied: faker in c:\users\arunkumar\.android\new folder\lib\site-packages (37.1.0)
# Requirement already satisfied: streamlit in c:\users\arunkumar\.android\new folder\lib\site-packages (1.37.1)
# Requirement already satisfied: tzdata in c:\users\arunkumar\.android\new folder\lib\site-packages (from faker) (2023.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\arunkumar\.android\new folder\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\arunkumar\.android\new folder\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\arunkumar\.android\new folder\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\arunkumar\.android\new folder\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arunkumar\.android\new folder\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arunkumar\.android\new folder\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arunkumar\.android\new folder\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arunkumar\.android\new folder\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\arunkumar\.android\new folder\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\arunkumar\.android\new folder\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\arunkumar\.android\new folder\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arunkumar\.android\new folder\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\arunkumar\.android\new folder\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
import sqlite3
from faker import Faker
import random
import pandas as pd
from datetime import datetime

# %%
class DatabaseManager:
    def __init__(self, db_name="students.db"):
        self.db_name = db_name

    def create_tables(self):
        conn = sqlite3.connect(self.db_name)
        cursor = conn.cursor()
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS students (
                student_id INTEGER PRIMARY KEY,
                name TEXT, age INTEGER, email TEXT, phone TEXT, enrollment_date TEXT
            );
        """)
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS programming (
                student_id INTEGER, language TEXT,
                problems_solved INTEGER, assessments_completed INTEGER, projects_submitted INTEGER,
                FOREIGN KEY (student_id) REFERENCES students(student_id)
            );
        """)
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS soft_skills (
                student_id INTEGER,
                communication_score INTEGER, teamwork_score INTEGER, presentation_score INTEGER,
                FOREIGN KEY (student_id) REFERENCES students(student_id)
            );
        """)
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS placements (
                student_id INTEGER,
                placement_ready TEXT, mock_interview_score INTEGER, internship_experience TEXT,
                FOREIGN KEY (student_id) REFERENCES students(student_id)
            );
        """)
        conn.commit()
        conn.close()

    def insert(self, table, data):
        try:
            conn = sqlite3.connect(self.db_name, check_same_thread=False)
            cursor = conn.cursor()
            placeholders = ','.join('?' * len(data[0]))
            cursor.executemany(f"INSERT INTO {table} VALUES ({placeholders})", data)
            conn.commit()
        except sqlite3.OperationalError as e:
            print("Error inserting data:", e)
        finally:
            conn.close()

# %%
fake = Faker()

def generate_students(n=5):
    return [
        (
            i,
            fake.name(),
            random.randint(118,135),
            fake.email(),
            fake.phone_number(),
            fake.date_between(start_date='-2y', end_date='today').isoformat()
        ) for i in range(1, n + 1)
    ]

def generate_programming(n=5):
    return [(i, 'Python', random.randint(20, 100), random.randint(1, 5), random.randint(0, 3)) for i in range(1, n+1)]

def generate_soft_skills(n=5):
    return [(i, random.randint(60, 100), random.randint(60, 100), random.randint(60, 100)) for i in range(1, n+1)]

def generate_placements(n=5):
    return [(i, random.choice(['Yes', 'No']), random.randint(40, 100), random.choice(['Yes', 'No'])) for i in range(1, n+1)]

# %%
db = DatabaseManager()
db.create_tables()

students = generate_students()
programming = generate_programming()
soft_skills = generate_soft_skills()
placements = generate_placements()

db.insert("students", students)
db.insert("programming", programming)
db.insert("soft_skills", soft_skills)
db.insert("placements", placements)

# %%
conn = sqlite3.connect("students.db")
df = pd.read_sql_query('''
SELECT s.name, p.problems_solved, 
       (ss.communication_score + ss.teamwork_score + ss.presentation_score)/3.0 AS soft_skills_avg,
       place.placement_ready
FROM students s
JOIN programming p ON s.student_id = p.student_id
JOIN soft_skills ss ON s.student_id = ss.student_id
JOIN placements place ON s.student_id = place.student_id;
''', conn)
df
# Out:
#                name  problems_solved  soft_skills_avg placement_ready
# 0       Alan Jordan               93        76.666667             Yes
# 1       Frank Moore               62        83.333333             Yes
# 2       Megan Lopez               73        81.000000             Yes
# 3  Kimberly Randall               37        78.666667             Yes
# 4      Steven Scott               55        81.333333             Yes
